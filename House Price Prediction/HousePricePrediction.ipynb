# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import mpl_toolkits

# %%
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/divya/Documents/projects/House Price Prediction/kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data['bedrooms'].value_counts().plot(kind="bar")
plt.title("No. of Bedrooms")
plt.xlabel("Bedrooms")
plt.ylabel("count")
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10, 10))
sns.jointplot(x = data.lat.values, y = data.long.values, size = 10)
plt.title("Distribution of houses based on location")
plt.xlabel("Latitude", fontsize = 12)
plt.ylabel("Longitude", fontsize = 12)
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\divya\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.scatter(data.price, data.sqft_living)
plt.title("Price vs Square Feet")
plt.xlabel("Price")
plt.ylabel("Squarefeet of Living Area")
# Out:
# Text(0,0.5,'Squarefeet of Living Area')

# %%
plt.scatter(data.price, data.long)
plt.title("Price vs Longitude")
plt.xlabel("Price")
plt.ylabel("Longitude")
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.price, data.lat)
plt.title("Price vs Latitude")
plt.xlabel("Price")
plt.ylabel("Latitude")
# Out:
# Text(0,0.5,'Latitude')

# %%
plt.scatter(data.bedrooms, data.price)
plt.title("No. of Bedrooms vs Price")
plt.xlabel("No. of Bedrooms")
plt.ylabel("Price")
# Out:
# Text(0,0.5,'Price')

# %%
plt.scatter(data.sqft_living + data.sqft_basement, data.price)
plt.title("Total Squarefeet vs Price")
plt.xlabel("Total Squarefeet")
plt.ylabel("Price")
# Out:
# Text(0,0.5,'Price')

# %%
plt.scatter(data.floors, data.price)
plt.title("No. of floors vs Price")
plt.xlabel("No. of floors")
plt.ylabel("Price")
# Out:
# Text(0,0.5,'Price')

# %%
plt.scatter(data.condition, data.price)
plt.title("House Condition vs Price")
plt.xlabel("Condition")
plt.ylabel("Price")
# Out:
# Text(0,0.5,'Price')

# %%
plt.scatter(data.zipcode, data.price)
plt.title("Location(Zip Code) vs Price")
plt.xlabel("Zip Code")
plt.ylabel("Price")
# Out:
# Text(0,0.5,'Price')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = data['price']

# %%
conv_dates = [1 if values == 2014 else 0 for values in data.date]

# %%
data['date'] = conv_dates

# %%
train1 = data.drop(['id', 'price'], axis = 1)

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\divya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train, x_test, y_train, y_test = train_test_split(train1, labels, test_size = 0.10, random_state = 2)

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.score(x_test, y_test)
# Out:
# 0.7320342760357672

# %%
from sklearn import ensemble

# %%
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2, learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=5, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=400, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
clf.score(x_test, y_test)
# Out:
# 0.9193507491695504
